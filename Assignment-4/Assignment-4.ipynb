# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
path = "student-mat.csv"
data = pd.read_csv(path, delimiter=';')

# Select relevant columns
selected_columns = ["freetime", "studytime"]
selected_data = data[selected_columns]

# Calculate the correlation matrix
correlations = selected_data.corr()

# Create a heatmap
plt.figure(figsize=(5, 5))  # Adjust the figure size as needed
sns.heatmap(correlations, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation between Freetime and Studytime")
plt.show()

# %%
# Select only the numeric attributes
numeric_data = data.select_dtypes(include=['int64', 'float64'])

# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True)
plt.title("Correlation Matrix of Numeric Attributes")
plt.show()
